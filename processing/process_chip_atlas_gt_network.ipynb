# %%
import pandas as pd
import sys
sys.path.append('/home/vinas/bedtools')
import pybedtools
from pybedtools import BedTool

# %%
data_dir = '/mlbio_scratch/vinas/chip-atlas'
pybedtools.set_tempdir('/mlbio_scratch/vinas/tmp')

# %% [markdown]
# #### Load metadata

# %%
ncols = 15
experiment_df = pd.read_csv(f'{data_dir}/experimentList.tab',
                            delimiter='\t',
                            header=None,
                            usecols=list(range(ncols))) # on_bad_lines='skip',
# Ref: https://github.com/inutano/chip-atlas/wiki#experimentList_schema
experiment_df.columns = ['exp_id', 'genome', 'track_type_class', 'track_type',
                         'cell_type_class', 'cell_type', 'cell_type_description',
                         'processing_logs', 'processing_logs_bisulfite_seq',
                         'title', 'metadata_1', 'metadata_2', 'metadata_3', 'metadata_4', 'metadata_5']
mouse_experiment_df = experiment_df[experiment_df['genome'] == 'mm10']
df = mouse_experiment_df[mouse_experiment_df['cell_type_class'].isin(['Pluripotent stem cell'])]
df = df[df['track_type_class'] == 'TFs and others']
df
# Out:
#            exp_id genome track_type_class track_type        cell_type_class  \
# 434383  DRX000343   mm10   TFs and others       Chd2  Pluripotent stem cell
# 434557  DRX013314   mm10   TFs and others      Kdm1a  Pluripotent stem cell
# 434562  DRX013319   mm10   TFs and others       Rest  Pluripotent stem cell
# 434563  DRX013320   mm10   TFs and others      Rcor2  Pluripotent stem cell
# 434564  DRX013321   mm10   TFs and others      Ehmt2  Pluripotent stem cell
# ...           ...    ...              ...        ...                    ...
# 589026  SRX997158   mm10   TFs and others       Brd4  Pluripotent stem cell
# 589027  SRX997159   mm10   TFs and others       Brd2  Pluripotent stem cell
# 589028  SRX997160   mm10   TFs and others       Brd2  Pluripotent stem cell
# 589029  SRX997161   mm10   TFs and others       Brd4  Pluripotent stem cell
# 589030  SRX997162   mm10   TFs and others       Brd4  Pluripotent stem cell
#
#        cell_type cell_type_description            processing_logs  \
# 434383  ES cells                   NaN        3576947,95.1,9.9,93
# 434557     EpiSC                   NaN  104699053,85.6,38.5,19216
# 434562     EpiSC                   NaN   72899748,36.2,83.5,17692
# 434563     EpiSC                   NaN   70560067,33.8,83.3,14412
# 434564     EpiSC                   NaN   56839755,41.2,77.9,13087
# ...          ...                   ...                        ...
# 589026  ES cells                   NaN    25333917,98.0,48.8,6833
# 589027  ES cells                   NaN   25681235,98.0,47.7,20053
# 589028  ES cells                   NaN    19240486,98.1,69.6,8589
# 589029  ES cells                   NaN    24511162,97.3,57.8,7980
# 589030  ES cells                   NaN    26529089,97.7,42.2,8530
#
#                             processing_logs_bisulfite_seq  \
# 434383                  ES CHD2 ChIP-Seq 20100705 Elution
# 434557                                           Epi-Lsd1
# 434562                                           Epi-REST
# 434563                                         Epi-COREST
# 434564                                            Epi-G9a
# ...                                                   ...
# 589026  GSM1659409: WT Brd4 ChIP-seq Rep 2; Mus muscul...
# 589027  GSM1659410: K3R3 Brd2 ChIP-seq Rep 1; Mus musc...
# 589028  GSM1659411: K3R3 Brd2 ChIP-seq Rep 2; Mus musc...
# 589029  GSM1659412: K3R3 Brd4 ChIP-seq Rep 1; Mus musc...
# 589030  GSM1659413: K3R3 Brd4 ChIP-seq Rep 2; Mus musc...
#
#                                  title  \
# 434383           sample_name=DRS000311
# 434557           sample_name=DRS013077
# 434562           sample_name=DRS013082
# 434563           sample_name=DRS013083
# 434564           sample_name=DRS013084
# ...                                ...
# 589026    source_name=WT Brd4 ChIP-seq
# 589027  source_name=K3R3 Brd2 ChIP-seq
# 589028  source_name=K3R3 Brd2 ChIP-seq
# 589029  source_name=K3R3 Brd4 ChIP-seq
# 589030  source_name=K3R3 Brd4 ChIP-seq
#
#                                                metadata_1  \
# 434383                                     strain=129/Ola
# 434557  sample comment=EpiSC cells were cultured on mu...
# 434562  sample comment=EpiSC cells were cultured on mu...
# 434563  sample comment=EpiSC cells were cultured on mu...
# 434564  sample comment=EpiSC cells were cultured on mu...
# ...                                                   ...
# 589026          strain background=V6.5 (129SvJaexC57BL/6)
# 589027          strain background=V6.5 (129SvJaexC57BL/6)
# 589028          strain background=V6.5 (129SvJaexC57BL/6)
# 589029          strain background=V6.5 (129SvJaexC57BL/6)
# 589030          strain background=V6.5 (129SvJaexC57BL/6)
#
#                                                metadata_2  \
# 434383  sample comment=mouse EB5 cell lines medium con...
# 434557                                                NaN
# 434562                                                NaN
# 434563                                                NaN
# 434564                                                NaN
# ...                                                   ...
# 589026              cell type=Embryonic stem cells (ESCs)
# 589027              cell type=Embryonic stem cells (ESCs)
# 589028              cell type=Embryonic stem cells (ESCs)
# 589029              cell type=Embryonic stem cells (ESCs)
# 589030              cell type=Embryonic stem cells (ESCs)
#
#                               metadata_3  \
# 434383                     cell_line=EB5
# 434557                               NaN
# 434562                               NaN
# 434563                               NaN
# 434564                               NaN
# ...                                  ...
# 589026    transfected with=H2A.Z(WT)-YFP
# 589027  transfected with=H2A.Z(K3R3)-YFP
# 589028  transfected with=H2A.Z(K3R3)-YFP
# 589029  transfected with=H2A.Z(K3R3)-YFP
# 589030  transfected with=H2A.Z(K3R3)-YFP
#
#                                                metadata_4  \
# 434383                                                NaN
# 434557                                                NaN
# 434562                                                NaN
# 434563                                                NaN
# 434564                                                NaN
# ...                                                   ...
# 589026      genotype/variation=expressing wild type H2A.Z
# 589027  genotype/variation=expressing a ubiquitin muta...
# 589028  genotype/variation=expressing a ubiquitin muta...
# 589029  genotype/variation=expressing a ubiquitin muta...
# 589030  genotype/variation=expressing a ubiquitin muta...
#
#                                             metadata_5
# 434383                                             NaN
# 434557                                             NaN
# 434562                                             NaN
# 434563                                             NaN
# 434564                                             NaN
# ...                                                ...
# 589026  chip antibody=Brd4 (Bethyl A301-985A50, lot 3)
# 589027    chip antibody=Brd2 (Bethyl A302-583A, lot 1)
# 589028    chip antibody=Brd2 (Bethyl A302-583A, lot 1)
# 589029  chip antibody=Brd4 (Bethyl A301-985A50, lot 3)
# 589030  chip antibody=Brd4 (Bethyl A301-985A50, lot 3)
#
# [7339 rows x 15 columns]

# %% [markdown]
# #### Filter relevant peaks

# %%
chip = BedTool(f'{data_dir}/allPeaks_light.mm10.05.bed.gz')
unique_exp_ids = df['exp_id'].unique()
chip_filtered = chip.filter(lambda x: x[3] in unique_exp_ids)
chip_filtered = chip_filtered.saveas(f'{data_dir}/mouse_stem_peaks.mm10.05.bed')
chip_filtered

# %% [markdown]
# #### MM10 (ENSEMBL 96) genome

# %%
mm10_df = pd.read_csv(f'{data_dir}/Mus_musculus.ENS96.csv', index_col=0)
mm10_df['chr'] = 'chr'+mm10_df.index
mm10_df.to_csv(f'{data_dir}/Mus_musculus.ENS96.tsv', header=None, sep='\t')
mm10_df.set_index('chr')[['chromStart', 'chromEnd', 'gene_id']].to_csv(f'{data_dir}/Mus_musculus_3col.ENS96.tsv', header=None, sep='\t')

# %% [markdown]
# #### Intersect

# %%
chip_filtered = BedTool(f'{data_dir}/mouse_stem_embryo_peaks.mm10.05.bed')
genes = BedTool(f'{data_dir}/Mus_musculus_3col.ENS96.tsv')
mapped_genes = chip_filtered.intersect(genes, wo=True).moveto(f'{data_dir}/mm10_stem_cells_chip_atlas_network.bed')

# %% [markdown]
# #### Matched peaks

# %%
matched_df = pd.read_csv(f'{data_dir}/mm10_stem_cells_chip_atlas_network.bed', delimiter='\t', header=None)
matched_df.columns = ['chr_1', 'start_1', 'end_1', 'exp_id', 'MACS2', 'chr_2', 'start_2', 'end_2', 'TG', 'overlap']
matched_df = matched_df[matched_df['exp_id'].isin(df['exp_id'].unique())]
matched_df
# Out:
#          chr_1   start_1     end_1       exp_id  MACS2 chr_2   start_2  \
# 0         chr1   3102101   3102502   SRX1410928    129  chr1   3102016
# 1         chr1   3206037   3206465   SRX7001433    430  chr1   3205901
# 2         chr1   3206082   3206420  SRX14812472    531  chr1   3205901
# 3         chr1   3206088   3206450  SRX14812473    439  chr1   3205901
# 4         chr1   3206103   3206433  SRX18990882    418  chr1   3205901
# ...        ...       ...       ...          ...    ...   ...       ...
# 58202268  chrY  90843980  90844175   SRX3581851    119  chrY  90837413
# 58202269  chrY  90843989  90844072    SRX823726     88  chrY  90837413
# 58202270  chrY  90843990  90844039    SRX868174     89  chrY  90837413
# 58202271  chrY  90843990  90844062    SRX555895     97  chrY  90837413
# 58202272  chrY  90844026  90844503  SRX20660260    107  chrY  90837413
#
#              end_2                  TG  overlap
# 0          3102125  ENSMUSG00000064842       24
# 1          3671498  ENSMUSG00000051951      428
# 2          3671498  ENSMUSG00000051951      338
# 3          3671498  ENSMUSG00000051951      362
# 4          3671498  ENSMUSG00000051951      330
# ...            ...                 ...      ...
# 58202268  90844040  ENSMUSG00000099871       60
# 58202269  90844040  ENSMUSG00000099871       51
# 58202270  90844040  ENSMUSG00000099871       49
# 58202271  90844040  ENSMUSG00000099871       50
# 58202272  90844040  ENSMUSG00000099871       14
#
# [58202273 rows x 10 columns]

# %%
df_ = df.set_index('exp_id').loc[matched_df['exp_id']]
matched_df['TF_name'] = df_['track_type'].values
matched_df['cell_type'] = df_['cell_type'].values
# Out:
# /tmp/ipykernel_1199932/3129011447.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_df['TF'] = df_['track_type'].values
# /tmp/ipykernel_1199932/3129011447.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_df['cell_type'] = df_['cell_type'].values

# %%
genes_df = pd.read_csv(f'{data_dir}/Mus_musculus.ENS96.csv')
genes_df_ = genes_df.set_index('gene_id')
matched_df['TG_name'] = genes_df_.loc[matched_df['TG']]['gene_name'].values
matched_df
# Out:
# /tmp/ipykernel_1199932/2530099654.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_df['TG_name'] = genes_df_.loc[matched_df['TG']]['gene_name'].values
#          chr_1   start_1     end_1       exp_id  MACS2 chr_2   start_2  \
# 0         chr1   3102101   3102502   SRX1410928    129  chr1   3102016
# 1         chr1   3206037   3206465   SRX7001433    430  chr1   3205901
# 2         chr1   3206082   3206420  SRX14812472    531  chr1   3205901
# 3         chr1   3206088   3206450  SRX14812473    439  chr1   3205901
# 4         chr1   3206103   3206433  SRX18990882    418  chr1   3205901
# ...        ...       ...       ...          ...    ...   ...       ...
# 58202268  chrY  90843980  90844175   SRX3581851    119  chrY  90837413
# 58202269  chrY  90843989  90844072    SRX823726     88  chrY  90837413
# 58202270  chrY  90843990  90844039    SRX868174     89  chrY  90837413
# 58202271  chrY  90843990  90844062    SRX555895     97  chrY  90837413
# 58202272  chrY  90844026  90844503  SRX20660260    107  chrY  90837413
#
#              end_2                  TG  overlap            TF  \
# 0          3102125  ENSMUSG00000064842       24        Pou3f1
# 1          3671498  ENSMUSG00000051951      428         Trp53
# 2          3671498  ENSMUSG00000051951      338        Trim24
# 3          3671498  ENSMUSG00000051951      362        Trim24
# 4          3671498  ENSMUSG00000051951      330         Trp53
# ...            ...                 ...      ...           ...
# 58202268  90844040  ENSMUSG00000099871       60          Cbx3
# 58202269  90844040  ENSMUSG00000099871       51          Aff3
# 58202270  90844040  ENSMUSG00000099871       49         Fgfr1
# 58202271  90844040  ENSMUSG00000099871       50         Dppa2
# 58202272  90844040  ENSMUSG00000099871       14  Epitope tags
#
#                           cell_type  TG_name
# 0                             EpiSC  Gm26206
# 1                          ES cells     Xkr4
# 2                          ES cells     Xkr4
# 3                          ES cells     Xkr4
# 4         mESC derived neural cells     Xkr4
# ...                             ...      ...
# 58202268                   ES cells  Gm21742
# 58202269                   ES cells  Gm21742
# 58202270                   ES cells  Gm21742
# 58202271                   ES cells  Gm21742
# 58202272                   ES cells  Gm21742
#
# [52958674 rows x 13 columns]

# %%
matched_df.to_csv(f'{data_dir}/mm10_stem_cells_chip_atlas_network.csv')

# %%
matched_df['cell_type'].value_counts()
# Out:
# cell_type
# ES cells                                      41213335
# Embryoid Bodies                                2279598
# iPS cells                                      1596013
# mESCs, differentiated                          1483780
# mESC derived neural cells                      1388218
# EpiLC                                          1070463
# EpiSC                                           656975
# F9                                              555079
# iPSC intermediates                              472510
# PGCLC                                           327595
# mESC derived erythroid cells                    283773
# P19                                             279510
# mESC derived haematopoietic progenitor          252373
# mESC derived endodermal cells                   175280
# mESC derived mesodermal cells                   164156
# mESC derived haemogenic endothelium             132932
# ZHBTc4                                          105961
# Germline stem cell-like cells                    99583
# mESC derived cardiac cells                       91564
# mESC derived macrophages                         84043
# Extended pluripotent stem cells                  68031
# NSC-derived iPS cells                            63857
# EpiSCs derived oligodendrocyte progenitors       57352
# ATDC-5                                           36465
# mESC derived myeloid progenitors                 17740
# mESC derived glial cells                          1395
# P19 derived neural cells                           507
# mESC derived epiblast-like cells                   447
# mESC derived notochord cells                       139
# Name: count, dtype: int64
